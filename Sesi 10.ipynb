# %% [markdown]
# # Inferential Statistics

# %%
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image

# %%
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# ## Uniform Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import uniform

# %%
data_uniform = uniform.rvs(size=10000, loc=10, scale=10)

# %%
sns.distplot(data_uniform)
plt.title('Uniform Distribution Plot')
plt.show()
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Normal Distribution

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from scipy.stats import norm 
data_normal = norm.rvs(size=10000,loc=0,scale=1)
sns.displot(data_normal)
plt.show()

# %% [markdown]
# ## Gamma Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(size=10000, a=10)

# %%
sns.distplot(data_gamma)
plt.show()
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import expon 
data_expon = expon.rvs(scale=1,loc=0,size=1000)

# %%
sns.distplot(data_expon)
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Poisson Distribution (Discrete/Count Data)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size = 10000)

# %%
sns.distplot(data_poisson)
plt.show()
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Binomial Distribution (Discrete)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10, p=0.8, size=10000)

# %%
sns.distplot(data_binom)
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Bernoulli Distribution

# %%
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000, p=0.6)
sns.displot(data_bern)
plt.show()

# %% [markdown]
# ## Confidence Interval

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Confidence Interval 95% Maka Z-Score 1.96

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd 
import numpy as np
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df['sex1'] = df.sex.replace({1:'Male', 0:'Female'})

# %%
def sex_label(x):
    if x==1:
        return 'Male'
    else:
        return 'Female'

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target    sex1
# 0         2   2     3       0    Male
# 1         0   0     3       0    Male
# 2         0   0     3       0    Male
# 3         2   1     3       0    Male
# 4         1   3     2       0  Female
# ...     ...  ..   ...     ...     ...
# 1020      2   0     2       1    Male
# 1021      1   1     3       0    Male
# 1022      1   1     2       0    Male
# 1023      2   0     2       1  Female
# 1024      1   1     3       0    Male
#
# [1025 rows x 15 columns]

# %% [markdown]
# Target 1 itu sakit jantung, 0 bukan penderita sakit jantung

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
#  14  sex1      1025 non-null   object
# dtypes: float64(1), int64(13), object(1)
# memory usage: 120.2+ KB

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# sex1        0
# dtype: int64

# %%
df.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.groupby(['sex1','target'])[['target']].count()
# Out:
#                target
# sex1   target
# Female 0           86
#        1          226
# Male   0          413
#        1          300

# %%
n = 86+226
pro_fem = 226/n
print(n, pro_fem)
# Out:
# 312 0.7243589743589743

# %%
stderror_fm = (pro_fem*(1-pro_fem)/n)**(1/2)
stderror_fm
# Out:
# 0.02529714756803247

# %% [markdown]
# Ambil confidence interval 95% yaitu Z-Score 1.96

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z_score = 1.96
low_ci_fm = pro_fem - (z_score*stderror_fm)
up_ci_fm = pro_fem + (z_score*stderror_fm)
print(low_ci_fm, up_ci_fm)
# Out:
# 0.6747765651256307 0.773941383592318

# %%
margin_error = (z_score*stderror_fm)
margin_error
# Out:
# 0.049582409233343644

# %% [markdown]
# ## Contoh Lain

# %%
import scipy.stats as stats
import random
import warnings

# %% [markdown]
# ### Generate Massa Populasi dalam Pounds dibagi menjadi wanita dan pria

# %%
normal_distribution_male = norm.rvs(loc=181, scale=24, size=6000)
normal_distribution_female = norm.rvs(loc=132, scale=22, size=6500)
all_mass = np.concatenate([normal_distribution_male,normal_distribution_female], axis=0)
df_mass = pd.DataFrame(all_mass, columns=['people_mass'])
df_mass
# Out:
#        people_mass
# 0       144.488467
# 1       217.581254
# 2       171.690352
# 3       118.953468
# 4       192.201904
# ...            ...
# 12495   128.879928
# 12496   172.117848
# 12497   156.234346
# 12498   145.914113
# 12499   132.083939
#
# [12500 rows x 1 columns]

# %%
sns.displot(df_mass['people_mass'])
plt.ylabel('Probability of Occurence')
plt.xlabel('Mass(Pounds)')
plt.show()

# %%
len(all_mass)
# Out:
# 12500

# %%
# Mean
population_mean = df_mass['people_mass'].mean()
population_mean
# Out:
# 155.8750779035812

# %%
# Standard Deviation
population_std = df_mass['people_mass'].std(ddof=1)
population_std
# Out:
# 33.658786786460205

# %% [markdown]
# Kita mengambil 250 sampel masing-masing sebanyak 30 orang per sampel

# %%
n = 30 
sample_means =[]
for sample in range(0,250):
    sample_values = df_mass['people_mass'].sample(n)
    sample_mean = sample_values.mean()
    sample_means.append(sample_mean)

# %%
np.random.choice(a=df_mass['people_mass'],size=10)
# Out:
# array([141.40616793, 106.9749573 , 128.59605857, 136.57079073,
#        156.09022799, 164.51569366, 147.42774741, 120.84663865,
#        174.47902374, 157.52524935])

# %%
df_mass['people_mass'].sample(10)
# Out:
# 11039    133.412088
# 12161    109.044909
# 4679     153.583919
# 8915     136.867428
# 9731     145.909276
# 7707     116.393043
# 3787     156.896123
# 4623     186.317107
# 6725     123.537550
# 9836     122.322316
# Name: people_mass, dtype: float64

# %%
sns.displot(sample_means)

# %%
mean_of_sample_means = np.mean(sample_means)
median_of_sample_means = np.median(sample_means)
mean_of_sample_means, median_of_sample_means
# Out:
# (156.21697857372365, 156.13950879404126)

# %%
population_mean
# Out:
# 155.8750779035812

# %%
std_of_sample_means = np.std(sample_means)
std_of_sample_means
# Out:
# 6.170090382910983

# %%
standard_error = population_std/np.sqrt(n)
standard_error
# Out:
# 6.1452255937336915

# %%
std_of_sample_means
# Out:
# 6.170090382910983

# %% [markdown]
# Kesimpulan Sample memiliki karakteristik yang serupa dengan populasi

# %% [markdown]
# ## Visualisasikan Area dari Confidence Interval

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)stats

# %%
stats.norm.cdf(2.17)
# Out:
# 0.9849965770262678

# %%
z = 1.96

# %%
lower_bound = mean_of_sample_means - z * standard_error
lower_bound
# Out:
# 144.1723364100056

# %%
upper_bound = mean_of_sample_means + z * standard_error
upper_bound
# Out:
# 168.2616207374417

# %%
kde = stats.gaussian_kde(sample_means)
pos = np.linspace(np.min(sample_means),np.max(sample_means),10000)
plt.plot(pos,kde(pos))
shade = np.linspace(lower_bound,upper_bound,300)
plt.fill_between(shade,kde(shade), alpha=0.5)
plt.xlabel('Sample Mass (Pounds)')
plt.ylabel('Frequency')
plt.axvline(x=mean_of_sample_means, color='red')
plt.text(x=154, y=0.01, s='Shaded Area are part of the Confidence Intervals')
# Out:
# Text(154, 0.01, 'Shaded Area are part of the Confidence Intervals')

# %%
pos
# Out:
# array([141.7960086 , 141.79897294, 141.80193728, ..., 171.43049255,
#        171.43345689, 171.43642122])

# %% [markdown]
# ## Hypothesis Testing

# %%
pd.read_csv('heart.csv')
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nhanes_2015_2016.csv')

# %%
df
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0          1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1          2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2          1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3          1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4          1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
# ...        ...       ...  ...     ...     ...    ...    ...     ...     ...
# 5730       1.0       3.0  ...   112.0    46.0   59.1  165.8    21.5    38.2
# 5731       1.0       5.0  ...   116.0    76.0  112.1  182.2    33.8    43.4
# 5732       1.0       4.0  ...   146.0    58.0   71.7  152.2    31.0    31.3
# 5733       2.0       1.0  ...   106.0    66.0   78.2  173.3    26.0    40.3
# 5734       1.0       5.0  ...   114.0    68.0   58.3  165.0    21.4    38.2
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0        43.6     35.9     101.1     2.0
# 1        40.0     33.2     107.9     NaN
# 2        37.0     31.0     116.5     2.0
# 3        37.7     38.3     110.1     2.0
# 4        36.0     27.2      80.4     2.0
# ...       ...      ...       ...     ...
# 5730     37.0     29.5      95.0     2.0
# 5731     41.8     42.3     110.2     2.0
# 5732     37.5     28.8       NaN     2.0
# 5733     37.5     30.6      98.9     2.0
# 5734     33.5     26.2      72.5     2.0
#
# [5735 rows x 28 columns]

# %% [markdown]
# Uji apakah rata-rata BMI dari laki laki lebih tinggi dari pada BMI perempuan

# %% [markdown]
#  H0 = Rata-rata BMI Laki-laki tidak lebih tinggi signifikan dari perempuan
#  H1 = Rata-rata BMI Laki-laki lebih tinggi signifikan dari perempuan

# %% [markdown]
# - H0 : meanL <= meanP
# - H1 : meanL > meanP

# %%
females = df[df.RIAGENDR==2]
males = df[df.RIAGENDR==1]

# %%
# Jumlah data, mean, dan stdeviasi
n_females = len(females)
mean_females = females['BMXBMI'].mean()
std_females = females['BMXBMI'].std()
print(n_females, mean_females, std_females)
# Out:
# 2976 29.939945652173996 7.75331880954568

# %%
n_males = len(males)
mean_males = males['BMXBMI'].mean()
std_males = males['BMXBMI'].std()
print(n_males, mean_males, std_males)
# Out:
# 2759 28.778072111846985 6.252567616801485

# %% [markdown]
# - H0 : meanL <= meanP
# - H1 : meanL > meanP

# %%
import statsmodels.api as sm

# %%
# Karena confidence level 95% maka alpha = 0.05
alpha = 0.05

# %%
bmi_hypo = sm.stats.ztest(males['BMXBMI'].dropna(),females['BMXBMI'].dropna(), alternative='larger')
bmi_hypo
# Out:
# (-6.1755933531383205, 0.9999999996704227)

# %%
if bmi_hypo[1]>alpha:
    print('Accept Null Hypothesis (H0) : Mean of Males BMI is not Larger than Females')
else:
    print('Reject Null Hypothesis (H0) : Mean of Males BMI is Larger than Females')
# Out:
# Accept Null Hypothesis (H0) : Mean of Males BMI is not Larger than Females

# %% [markdown]
# ## Data sama Hipotesis Berbeda

# %% [markdown]
# Uji apakah mean BMI Laki Laki tidak sama dengan mean BMI Perempuan

# %%
bmi_hypo_2s = sm.stats.ztest(males['BMXBMI'].dropna(),females['BMXBMI'].dropna(), alternative='two-sided')
bmi_hypo_2s
# Out:
# (-6.1755933531383205, 6.591544431126401e-10)

# %%
if bmi_hypo_2s[1]>alpha:
    print('Accept Null Hypothesis (H0) : Mean of Males BMI is not Larger than Females')
else:
    print('Reject Null Hypothesis (H0) : Mean of Males BMI is Larger than Females')
# Out:
# Reject Null Hypothesis (H0) : Mean of Males BMI is Larger than Females

# %% [markdown]
# # Hypothesis Testing Population Proportion

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 1018
pro_null = 0.52
pro_alter = 0.56

# %%
pro_hypo = sm.stats.proportions_ztest(n*pro_alter,n,pro_null, alternative='larger')
pro_hypo
# Out:
# (2.571067795759113, 0.005069273865860533)

# %%
if pro_hypo[1]>alpha:
    print('Accept Null Hypothesis (H0)')
else:
    print('Reject Null Hypothesis (H0)')
# Out:
# Reject Null Hypothesis (H0)

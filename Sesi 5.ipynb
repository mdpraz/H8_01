# %% [markdown]
# # PANDAS

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df.head(7)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id   fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH   Huskies  ...  40.294830     NYK        Knicks
# 1            0     NYK    Knicks  ...  41.705170     TRH       Huskies
# 2            0     CHS     Stags  ...  42.012257     NYK        Knicks
# 3            0     NYK    Knicks  ...  40.692783     CHS         Stags
# ...

# %%
#Jumlah row dari dataframe
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
# Top 5 row dari df
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
# Bottom 5 row daro df
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
a = np.array([[1,2,3],[4,5,6]])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
pd.set_option("display.max.columns", None)

df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# Mengubah data type columns df
df.gameorder = df.gameorder.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  object
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.gameorder = df.gameorder.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int32
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# melihat basic statistics
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
# Pengambilan satu kolom
df['elo_i'] # series 1D array
# Out:
# 0         1300.0000
# 1         1300.0000
# 2         1300.0000
# 3         1306.7233
# 4         1300.0000
#             ...
# 126309    1723.4149
# 126310    1809.9791
# 126311    1704.3949
# 126312    1700.7391
# 126313    1813.6349
# Name: elo_i, Length: 126314, dtype: float64

# %%
df[['elo_i']] # 2D array/Data Frame
# Out:
#             elo_i
# 0       1300.0000
# 1       1300.0000
# 2       1300.0000
# 3       1306.7233
# 4       1300.0000
# ...           ...
# 126309  1723.4149
# 126310  1809.9791
# 126311  1704.3949
# 126312  1700.7391
# 126313  1813.6349
#
# [126314 rows x 1 columns]

# %%
df.gameorder
# Out:
# 0             1
# 1             1
# 2             2
# 3             2
# 4             3
#           ...
# 126309    63155
# 126310    63156
# 126311    63156
# 126312    63157
# 126313    63157
# Name: gameorder, Length: 126314, dtype: int32

# %%
df[['gameorder']].shape
# Out:
# (126314, 1)

# %%
# Mengambil 10 data teratas beberapa kolom
df[['game_id','gameorder','year_id']].head(10)
# Out:
#         game_id  gameorder  year_id
# 0  194611010TRH          1     1947
# 1  194611010TRH          1     1947
# 2  194611020CHS          2     1947
# 3  194611020CHS          2     1947
# 4  194611020DTF          3     1947
# 5  194611020DTF          3     1947
# 6  194611020PRO          4     1947
# 7  194611020PRO          4     1947
# 8  194611020STB          5     1947
# 9  194611020STB          5     1947

# %%
# Value Counts = digunakan untuk melihat kumpulan data dari masing-masing tabel
df['year_id'].value_counts()
# Out:
# 2014    2638
# 2006    2638
# 2008    2632
# 2009    2630
# 2013    2628
#         ...
# 1959     620
# 1955     618
# 1958     618
# 1957     614
# 1948     430
# Name: year_id, Length: 69, dtype: int64

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
# Frekuensi suatu data
df['game_result'].value_counts()
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
# Frekuensi suatu data dalam bentuk persentase
df['game_result'].value_counts(normalize=True)*100
# Out:
# L    50.0
# W    50.0
# Name: game_result, dtype: float64

# %% [markdown]
# # Conditional Filtering

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df[df['seasongame']>60]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 660           331  194703310CHS   NBA        1     1947  3/31/1947
# 661           331  194703310CHS   NBA        0     1947  3/31/1947
# 662           332  194704020CLR   NBA        0     1947   4/2/1947
# 663           332  194704020CLR   NBA        1     1947   4/2/1947
# 664           333  194704020GSW   NBA        1     1947   4/2/1947
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 660             61            0     STB    Bombers   66  1374.8636  1369.4114
# ...

# %%
df[(df['seasongame']>60) & (df['fran_id']=='Knicks')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 663           332  194704020CLR   NBA        1     1947   4/2/1947
# 670           336  194704050NYK   NBA        0     1947   4/5/1947
# 678           340  194704090NYK   NBA        0     1947   4/9/1947
# 684           343  194704120GSW   NBA        1     1947  4/12/1947
# 689           345  194704140NYK   NBA        0     1947  4/14/1947
# ...           ...           ...   ...      ...      ...        ...
# 126025      63013  201504080NYK   NBA        0     2015   4/8/2015
# 126056      63029  201504100NYK   NBA        0     2015  4/10/2015
# 126072      63037  201504110ORL   NBA        1     2015  4/11/2015
# 126094      63048  201504130ATL   NBA        1     2015  4/13/2015
# 126147      63074  201504150NYK   NBA        0     2015  4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 663             61            1     NYK  Knicks   51  1332.1560  1316.3640
# ...

# %%
df[(df['seasongame']>60)&(df['fran_id']=='Knicks')][['seasongame','fran_id']]
# Out:
#         seasongame fran_id
# 663             61  Knicks
# 670             62  Knicks
# 678             63  Knicks
# 684             64  Knicks
# 689             65  Knicks
# ...            ...     ...
# 126025          78  Knicks
# 126056          79  Knicks
# 126072          80  Knicks
# 126094          81  Knicks
# 126147          82  Knicks
#
# [1638 rows x 2 columns]

# %%
df[(df['seasongame']>60)|(df['fran_id']=='Knicks')][['seasongame','fran_id']]
# Out:
#         seasongame    fran_id
# 1                1     Knicks
# 3                2     Knicks
# 23               3     Knicks
# 37               4     Knicks
# 54               5     Knicks
# ...            ...        ...
# 126309         100  Cavaliers
# 126310         102   Warriors
# 126311         101  Cavaliers
# 126312         102  Cavaliers
# 126313         103   Warriors
#
# [41576 rows x 2 columns]

# %% [markdown]
# ## Filter df dengan kondisi :
# - fran_id = Cavaliers dan pts >= 40 dan opp_pts <= 80

# %%
df[(df['opp_pts']<=80)&(df['pts']>=40)&(df['fran_id']=='Cavaliers')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 22899       11450  197101190BUF   NBA        1     1971   1/19/1971
# 29591       14796  197312050PHI   NBA        1     1974   12/5/1973
# 31746       15874  197411210CLE   NBA        0     1975  11/21/1974
# 32168       16085  197412230CLE   NBA        0     1975  12/23/1974
# 34244       17123  197512020CLE   NBA        0     1976   12/2/1975
# ...           ...           ...   ...      ...      ...         ...
# 123238      61620  201403300CLE   NBA        0     2014   3/30/2014
# 124088      62045  201411240CLE   NBA        0     2015  11/24/2014
# 125473      62737  201503030CLE   NBA        0     2015    3/3/2015
# 125534      62768  201503070CLE   NBA        0     2015    3/7/2015
# 126274      63138  201505140CHI   NBA        1     2015   5/14/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %% [markdown]
# # loc & iloc

# %%
df.iloc[2] #akan mengakses data berdasarkan indeks
# Out:
# gameorder                   2
# game_id          194611020CHS
# lg_id                     NBA
# _iscopy                     0
# year_id                  1947
# date_game           11/2/1946
# seasongame                  1
# is_playoffs                 0
# team_id                   CHS
# fran_id                 Stags
# pts                        63
# elo_i                  1300.0
# elo_n               1309.6521
# win_equiv           42.012257
# opp_id                    NYK
# opp_fran               Knicks
# opp_pts                    47
# opp_elo_i           1306.7233
# opp_elo_n           1297.0712
# game_location               H
# game_result                 W
# forecast             0.631101
# notes                     NaN
# Name: 2, dtype: object

# %%
df.loc[2] #akses data berdasarkan label
# Out:
# gameorder                   2
# game_id          194611020CHS
# lg_id                     NBA
# _iscopy                     0
# year_id                  1947
# date_game           11/2/1946
# seasongame                  1
# is_playoffs                 0
# team_id                   CHS
# fran_id                 Stags
# pts                        63
# elo_i                  1300.0
# elo_n               1309.6521
# win_equiv           42.012257
# opp_id                    NYK
# opp_fran               Knicks
# opp_pts                    47
# opp_elo_i           1306.7233
# opp_elo_n           1297.0712
# game_location               H
# game_result                 W
# forecast             0.631101
# notes                     NaN
# Name: 2, dtype: object

# %%
# Creating DataFrame
# 1. list
dflist = [[1,2,3],[4,5,6],[7,8,9]]
df_list = pd.DataFrame(dflist, columns= ['Jeruk','Mangga','Alpukat'], index=['Jakarta','Bandung','Bekasi'])
df_list
# Out:
#          Jeruk  Mangga  Alpukat
# Jakarta      1       2        3
# Bandung      4       5        6
# Bekasi       7       8        9

# %%
df_list.iloc[0]
# Out:
# Jeruk      1
# Mangga     2
# Alpukat    3
# Name: Jakarta, dtype: int64

# %%
df_list.loc['Bandung','Jeruk']
# Out:
# 4

# %%
df_list.iloc[0,1]
# Out:
# 2

# %%
df_list
# Out:
#          Jeruk  Mangga  Alpukat
# Jakarta      1       2        3
# Bandung      4       5        6
# Bekasi       7       8        9

# %%
df_list.iloc[0:2,0:3] #ada unsur star,stop
# Out:
#          Jeruk  Mangga  Alpukat
# Jakarta      1       2        3
# Bandung      4       5        6

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.iloc[5000:7001, 6:20]
# Out:
#       seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 5000          42            0     PHW   Warriors   85  1346.3630  1345.4856
# 5001          45            0     NYK     Knicks   90  1663.3676  1664.2450
# 5002          42            0     BLB  Baltimore   79  1358.2220  1355.9099
# 5003          45            0     SYR     Sixers   94  1620.1327  1622.4448
# 5004          46            0     SYR     Sixers   98  1622.4448  1630.7344
# ...          ...          ...     ...        ...  ...        ...        ...
# 6996          49            0     PHW   Warriors   93  1599.4049  1588.2762
# 6997          47            0     STL      Hawks  105  1511.3802  1522.5089
# 6998          49            0     SYR     Sixers   90  1537.7802  1542.7595
# 6999          47            0     FTW    Pistons   85  1551.4215  1546.4421
# 7000          50            0     SYR     Sixers   98  1542.7595  1540.1091
#
# ...

# %%
df.loc[5000:7000,'seasongame':'game_location']
# Out:
#       seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 5000          42            0     PHW   Warriors   85  1346.3630  1345.4856
# 5001          45            0     NYK     Knicks   90  1663.3676  1664.2450
# 5002          42            0     BLB  Baltimore   79  1358.2220  1355.9099
# 5003          45            0     SYR     Sixers   94  1620.1327  1622.4448
# 5004          46            0     SYR     Sixers   98  1622.4448  1630.7344
# ...          ...          ...     ...        ...  ...        ...        ...
# 6996          49            0     PHW   Warriors   93  1599.4049  1588.2762
# 6997          47            0     STL      Hawks  105  1511.3802  1522.5089
# 6998          49            0     SYR     Sixers   90  1537.7802  1542.7595
# 6999          47            0     FTW    Pistons   85  1551.4215  1546.4421
# 7000          50            0     SYR     Sixers   98  1542.7595  1540.1091
#
# ...

# %%
df.iloc[5000:7001, 6:20] #iloc urutan karena ada konsep start stop sehingga harus +1
# Out:
#       seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 5000          42            0     PHW   Warriors   85  1346.3630  1345.4856
# 5001          45            0     NYK     Knicks   90  1663.3676  1664.2450
# 5002          42            0     BLB  Baltimore   79  1358.2220  1355.9099
# 5003          45            0     SYR     Sixers   94  1620.1327  1622.4448
# 5004          46            0     SYR     Sixers   98  1622.4448  1630.7344
# ...          ...          ...     ...        ...  ...        ...        ...
# 6996          49            0     PHW   Warriors   93  1599.4049  1588.2762
# 6997          47            0     STL      Hawks  105  1511.3802  1522.5089
# 6998          49            0     SYR     Sixers   90  1537.7802  1542.7595
# 6999          47            0     FTW    Pistons   85  1551.4215  1546.4421
# 7000          50            0     SYR     Sixers   98  1542.7595  1540.1091
#
# ...

# %%
#2 DataFrame Dictionary
details = {
    'Nama' :['Handoko','Ajeng', 'Budi'],
    'Age' :[23,25,10],
    'Sex' :['L','P','L']
}
df_details = pd.DataFrame(details)
df_details
# Out:
#       Nama  Age Sex
# 0  Handoko   23   L
# 1    Ajeng   25   P
# 2     Budi   10   L

# %% [markdown]
# # Agregasi Tabel

# %%
df['seasongame'].sum()
# Out:
# 5498920

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# # Mengambil sum point oleh knicks pada tahun 2005

# %%
df_knicks_2005 = df[(df['fran_id']=='Knicks')&(df['year_id']==2005)] #/.['pts'].sum
df_knicks_2005['pts'].sum()
# Out:
# 7977

# %%
df.loc[(df['fran_id']=='Knicks')&(df['year_id']==2005),'pts'].sum()
# Out:
# 7977

# %% [markdown]
# # Agregasi lain

# %%
df.loc[(df['fran_id']=='Knicks')&(df['year_id']==2005),'pts'].max()
# Out:
# 135

# %%
df.loc[(df['fran_id']=='Knicks')&(df['year_id']==2005),'pts'].min()
# Out:
# 61

# %%
df.loc[(df['fran_id']=='Knicks')&(df['year_id']==2005),'pts'].mean()
# Out:
# 97.28048780487805

# %%
df.loc[(df['fran_id']=='Knicks')&(df['year_id']==2005),'pts'].median()
# Out:
# 96.0

# %%
df.loc[(df['fran_id']=='Knicks')&(df['year_id']==2005),'pts'].mode()
# Out:
# 0     91
# 1     93
# 2     94
# 3    113
# Name: pts, dtype: int64

# %%
df.loc[(df['fran_id']=='Knicks')&(df['year_id']==2005),'pts'].count()
# Out:
# 82

# %% [markdown]
# # Groupby

# %%
# Contohnya rata-rata poin pertim

df.groupby('fran_id')[['pts']].mean()
# Out:
#                      pts
# fran_id
# Baltimore      79.698073
# Bombers        71.457831
# Bucks         103.700050
# Bulls         101.525192
# Capitols       76.931271
# Cavaliers      99.846719
# Celtics       104.466233
# Clippers      101.934905
# Colonels      111.625296
# Condors       115.446512
# Denver         77.709677
# Falcons        63.283333
# Floridians    112.654545
# Grizzlies      95.161738
# Hawks         101.805635
# Heat           96.627162
# Hornets        94.506711
# Huskies        66.583333
# Ironmen        61.233333
# Jazz          102.153305
# Jets           74.700000
# Kings         103.971689
# Knicks        100.970185
# Lakers        105.817397
# Magic          99.427277
# Mavericks     102.634915
# Nets          101.755723
# Nuggets       108.199029
# Olympians      81.078014
# Pacers        103.687722
# Packers        86.013889
# Pelicans       97.956522
# Pistons       101.373097
# Raptors        96.921665
# Rebels         71.015873
# ...

# %%
# Contohnya rata-rata poin pertim
df.groupby('fran_id')[['pts']].max()
# Out:
#               pts
# fran_id
# Baltimore     126
# Bombers       109
# Bucks         166
# Bulls         156
# Capitols      118
# Cavaliers     154
# Celtics       173
# Clippers      152
# Colonels      157
# Condors       156
# Denver        108
# Falcons        92
# Floridians    160
# Grizzlies     144
# Hawks         155
# Heat          141
# Hornets       133
# Huskies        93
# Ironmen        85
# Jazz          153
# Jets          110
# Kings         165
# Knicks        152
# Lakers        162
# Magic         155
# Mavericks     156
# Nets          166
# Nuggets       184
# Olympians     112
# Pacers        177
# Packers       123
# Pelicans      141
# Pistons       186
# Raptors       136
# Rebels         92
# Redskins      141
# Rockets       156
# Sails         176
# Sixers        163
# Sounds        146
# Spirits       156
# Spurs         171
# Squires       169
# Stags         115
# Stars         154
# Steamrollers  107
# Suns          173
# Thunder       154
# ...

# %%
df.groupby(['fran_id','year_id'])[['pts']].mean()
# Out:
#                          pts
# fran_id   year_id
# Baltimore 1948     74.850000
#           1949     83.682540
#           1950     73.132353
#           1951     82.030303
#           1952     81.469697
# ...                      ...
# Wizards   2011     97.280488
#           2012     93.636364
#           2013     93.219512
#           2014     99.440860
#           2015     98.815217
#
# [1487 rows x 1 columns]

# %%
df[df['year_id']>2010].groupby(['year_id','fran_id'])[['pts']].mean()
# Out:
#                              pts
# year_id fran_id
# 2011    Bucks          91.878049
#         Bulls          97.622449
#         Cavaliers      95.451220
#         Celtics        96.318681
#         Clippers       98.646341
# ...                          ...
# 2015    Thunder       103.951220
#         Timberwolves   97.756098
#         Trailblazers  102.275862
#         Warriors      108.592233
#         Wizards        98.815217
#
# [150 rows x 1 columns]

# %%
df[df['year_id']>2005]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 100514      50258  200511010NOK   NBA        0     2006  11/1/2005
# 100515      50258  200511010NOK   NBA        1     2006  11/1/2005
# 100516      50259  200511010PHI   NBA        1     2006  11/1/2005
# 100517      50259  200511010PHI   NBA        0     2006  11/1/2005
# 100518      50260  200511010PHO   NBA        0     2006  11/1/2005
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 100514           1            0     NOK   Pelicans   93  1366.3867  1391.3676
# ...

# %%
df[(df['fran_id']=='Stags')&(df['year_id']==1950)].groupby(['game_location','game_result']).mean()
# Out:
#                              gameorder  _iscopy  year_id  seasongame  \
# game_location game_result
# A             L            1265.347826      1.0   1950.0   39.217391
#               W            1241.235294      1.0   1950.0   36.235294
# H             L            1304.750000      0.0   1950.0   43.500000
#               W            1188.000000      0.0   1950.0   30.000000
#
#                            is_playoffs        pts        elo_i        elo_n  \
# game_location game_result
# A             L               0.086957  75.391304  1544.391030  1536.226709
#               W               0.000000  83.705882  1540.549882  1549.300824
# H             L               0.125000  75.875000  1534.024813  1520.070187
#               W               0.000000  78.217391  1534.341022  1538.889735
#
#                            win_equiv    opp_pts    opp_elo_i    opp_elo_n  \
# game_location game_result
# A             L            49.749064  86.086957  1513.102317  1521.266635
# ...

# %%
df[(df['fran_id']=='Spurs')&(df['year_id']>2010)].groupby(['year_id','game_result']).mean()
# Out:
#                         gameorder   _iscopy  seasongame  is_playoffs  \
# year_id game_result
# 2011    L            57701.000000  0.760000   58.800000     0.160000
#         W            57407.126984  0.396825   38.825397     0.031746
# 2012    L            58657.400000  0.700000   36.350000     0.200000
#         W            58763.116667  0.433333   41.883333     0.166667
# 2013    L            60036.066667  0.733333   58.100000     0.200000
#         W            59916.616438  0.410959   49.493151     0.205479
# 2014    L            61332.074074  0.592593   55.777778     0.259259
#         W            61277.858974  0.448718   52.038462     0.205128
# 2015    L            62487.387097  0.677419   43.548387     0.129032
#         W            62525.982759  0.413793   45.775862     0.051724
#
#                             pts        elo_i        elo_n  win_equiv  \
# year_id game_result
# 2011    L             93.840000  1666.154764  1654.183612  55.992835
# ...

# %% [markdown]
# # Menggunakan Groupby lakukan analisis terhadap rata-rata skor yang dicetak Stags pada tahun 2004 dibagi berdasarkan game location dan game results

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df[(df['fran_id']=='Stags')&(df['year_id']==1947)].groupby(['game_location','game_result'])[['pts']].mean()
# Out:
#                                  pts
# game_location game_result
# A             L            71.352941
#               W            80.210526
# H             L            66.181818
#               W            80.320000

# %% [markdown]
# # Manipulating Columns

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
nba = df.copy()
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
# Tambah kolom
nba['difference'] = nba['pts'] - nba['opp_pts']
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# Penambahan kolom points^2
nba['Points^2'] = nba['pts']**2

# %%
nba.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# 0            0     TRH       Huskies   66  1300.0000  1293.2767  40.294830
# ...

# %%
# Perubahan kolom
nba['opp_pts'] = 100

# %%
nba['opp_pts'].value_counts()
# Out:
# 100    126314
# Name: opp_pts, dtype: int64

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes',
#        'difference', 'Points^2'],
#       dtype='object')

# %%
nba = nba[['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
       'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts','Points^2', 'elo_i',
       'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
       'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes',
       'difference']]

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  Points^2      elo_i  \
# 0                1            0     TRH    Huskies   66      4356  1300.0000
# ...

# %%
# rename column
# change game_result to result dan game_location to location
nbaa = nba.rename(columns={'game_result':'result', 'game_location':'location'})
nbaa.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  Points^2      elo_i      elo_n  \
# 0            0     TRH  Huskies   66      4356  1300.0000  1293.2767
# 1            0     NYK   Knicks   68      4624  1300.0000  1306.7233
# 2            0     CHS    Stags   63      3969  1300.0000  1309.6521
# 3            0     NYK   Knicks   47      2209  1306.7233  1297.0712
# 4            0     DTF  Falcons   33      1089  1300.0000  1279.6189
#
#    win_equiv opp_id  opp_fran  opp_pts  opp_elo_i  opp_elo_n location result  \
# ...

# %%
# Drop Columns
nba.drop('opp_elo_i', axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  Points^2      elo_i  \
# 0                1            0     TRH    Huskies   66      4356  1300.0000
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Points^2       126314 non-null  int64
#  12  elo_i          126314 non-null  float64
#  13  elo_n          126314 non-null  float64
#  14  win_equiv      126314 non-null  float64
#  15  opp_id         126314 non-null  object
#  16  opp_fran       126314 non-null  object
# ...

# %% [markdown]
# # Conversion Dtype

# %%
# Convert object to datetime
nba.date_game
# Out:
# 0         11/1/1946
# 1         11/1/1946
# 2         11/2/1946
# 3         11/2/1946
# 4         11/2/1946
#             ...
# 126309    6/11/2015
# 126310    6/14/2015
# 126311    6/14/2015
# 126312    6/16/2015
# 126313    6/16/2015
# Name: date_game, Length: 126314, dtype: object

# %%
nba['date_game'] = pd.to_datetime(nba.date_game)
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Points^2       126314 non-null  int64
#  12  elo_i          126314 non-null  float64
#  13  elo_n          126314 non-null  float64
#  14  win_equiv      126314 non-null  float64
#  15  opp_id         126314 non-null  object
#  16  opp_fran       126314 non-null  object
# ...

# %%
# !pip install datetime

# %%
nba[nba.date_game>pd.Timestamp(2005,1,10)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 98878       49440  200501110ATL   NBA        1     2005 2005-01-11
# 98879       49440  200501110ATL   NBA        0     2005 2005-01-11
# 98880       49441  200501110CLE   NBA        0     2005 2005-01-11
# 98881       49441  200501110CLE   NBA        1     2005 2005-01-11
# 98882       49442  200501110MEM   NBA        0     2005 2005-01-11
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  Points^2      elo_i  \
# 98878           32            0     MIL      Bucks   80      6400  1451.9478
# ...

# %%
nba[nba.date_game>pd.Timestamp(2005,1,10)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 98878       49440  200501110ATL   NBA        1     2005 2005-01-11
# 98879       49440  200501110ATL   NBA        0     2005 2005-01-11
# 98880       49441  200501110CLE   NBA        0     2005 2005-01-11
# 98881       49441  200501110CLE   NBA        1     2005 2005-01-11
# 98882       49442  200501110MEM   NBA        0     2005 2005-01-11
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 98878           32            0     MIL      Bucks   80  1451.9478  1431.2278
# ...

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df['fran_id'].unique()
# Out:
# array(['Huskies', 'Knicks', 'Stags', 'Falcons', 'Capitols', 'Celtics',
#        'Steamrollers', 'Ironmen', 'Bombers', 'Rebels', 'Warriors',
#        'Baltimore', 'Jets', 'Pistons', 'Lakers', 'Kings', 'Hawks',
#        'Denver', 'Olympians', 'Redskins', 'Waterloo', 'Packers', 'Sixers',
#        'Wizards', 'Bulls', 'Thunder', 'Squires', 'Stars', 'Rockets',
#        'Colonels', 'Pacers', 'Nuggets', 'Spurs', 'Spirits', 'Sounds',
#        'Floridians', 'Nets', 'Condors', 'Bucks', 'Suns', 'Clippers',
#        'Cavaliers', 'Trailblazers', 'Sails', 'Jazz', 'Mavericks',
#        'Pelicans', 'Heat', 'Timberwolves', 'Magic', 'Grizzlies',
#        'Raptors', 'Hornets'], dtype=object)

# %%
# Mengecek variabel unique
df['fran_id'].nunique()
# Out:
# 53

# %%
# Convert integer jadi float menggunakan astype
nba = df['gameorder'].astype(float)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  Points^2       126314 non-null  int64
#  12  elo_i          126314 non-null  float64
#  13  elo_n          126314 non-null  float64
#  14  win_equiv      126314 non-null  float64
#  15  opp_id         126314 non-null  object
#  16  opp_fran       126314 non-null  object
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# Convert data string jadi kapital
df['fran_id'].str.upper()
# Out:
# 0           HUSKIES
# 1            KNICKS
# 2             STAGS
# 3            KNICKS
# 4           FALCONS
#             ...
# 126309    CAVALIERS
# 126310     WARRIORS
# 126311    CAVALIERS
# 126312    CAVALIERS
# 126313     WARRIORS
# Name: fran_id, Length: 126314, dtype: object

# %% [markdown]
# # Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# gameorder             0
# game_id               0
# lg_id                 0
# _iscopy               0
# year_id               0
# date_game             0
# seasongame            0
# is_playoffs           0
# team_id               0
# fran_id               0
# pts                   0
# elo_i                 0
# elo_n                 0
# win_equiv             0
# opp_id                0
# opp_fran              0
# opp_pts               0
# opp_elo_i             0
# opp_elo_n             0
# game_location         0
# game_result           0
# forecast              0
# notes            120890
# dtype: int64

# %%
df[df['notes'].isna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
# Filter negasi dari isna
df[~(df.notes.isna())]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 930             28            0     WSC      Capitols   71  1469.3469
# ...

# %%
#dropna index
df.dropna()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 930             28            0     WSC      Capitols   71  1469.3469
# ...

# %%
#dropna columns
df.dropna(axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
#fillna
df['notes'].fillna('No Notes', inplace=True)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# gameorder        0
# game_id          0
# lg_id            0
# _iscopy          0
# year_id          0
# date_game        0
# seasongame       0
# is_playoffs      0
# team_id          0
# fran_id          0
# pts              0
# elo_i            0
# elo_n            0
# win_equiv        0
# opp_id           0
# opp_fran         0
# opp_pts          0
# opp_elo_i        0
# opp_elo_n        0
# game_location    0
# game_result      0
# forecast         0
# notes            0
# dtype: int64

# %% [markdown]
# # Combining Dataset

# %%
df_1 = pd.DataFrame({'Fisika':[70,74,91,85], 'Matematika':[60,75,77,90], 'Sejarah':[88,85,90,92]},
                     index=['Budi','Anwar','Joko','Samsul'])
df_1
# Out:
#         Fisika  Matematika  Sejarah
# Budi        70          60       88
# Anwar       74          75       85
# Joko        91          77       90
# Samsul      85          90       92

# %%
df_2 = pd.DataFrame({'Fisika':[70,74,91,85], 'Matematika':[60,75,77,90], 'Sejarah':[88,85,90,92]},
                     index=['Ani','Ana','Putri','Jelita'])
df_2
# Out:
#         Fisika  Matematika  Sejarah
# Ani         70          60       88
# Ana         74          75       85
# Putri       91          77       90
# Jelita      85          90       92

# %%
pd.concat([df_1,df_2])
# Out:
#         Fisika  Matematika  Sejarah
# Budi        70          60       88
# Anwar       74          75       85
# Joko        91          77       90
# Samsul      85          90       92
# Ani         70          60       88
# Ana         74          75       85
# Putri       91          77       90
# Jelita      85          90       92

# %%
# Merge
countries = pd.DataFrame({'Population' : [10,20,30],
                         'continent': ['Europe','Asia','Afrika'],
                         }, index=['Holland','Indonesia','Zimbabwe'])
countries
# Out:
#            Population continent
# Holland            10    Europe
# Indonesia          20      Asia
# Zimbabwe           30    Afrika

# %%
countries1 = pd.DataFrame({'President_gender' : ['M','M','M'],
                         'Minister': ['Yes','Yes','Yes'],
                         }, index=['Holland','Indonesia','Zimbabwe'])
countries1
# Out:
#           President_gender Minister
# Holland                  M      Yes
# Indonesia                M      Yes
# Zimbabwe                 M      Yes

# %%
pd.merge(countries,countries1,left_index=True,right_index=True)
# Out:
#            Population continent President_gender Minister
# Holland            10    Europe                M      Yes
# Indonesia          20      Asia                M      Yes
# Zimbabwe           30    Afrika                M      Yes

# %%
import seaborn as sns 
import numpy as np
mpg = sns.load_dataset('mpg')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg['horse_origin'] = mpg['horsepower']
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  horse_origin
# 0          70    usa  chevrolet chevelle malibu         130.0
# 1          70    usa          buick skylark 320         165.0
# 2          70    usa         plymouth satellite         150.0
# 3          70    usa              amc rebel sst         150.0
# 4          70    usa                ford torino         140.0

# %%
mpg.loc[mpg['horse_origin'] >= 105, 'horse_origin'] = 'lower ' + mpg['origin']

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  horse_origin
# 0          70    usa  chevrolet chevelle malibu         130.0
# 1          70    usa          buick skylark 320         165.0
# 2          70    usa         plymouth satellite         150.0
# 3          70    usa              amc rebel sst         150.0
# 4          70    usa                ford torino         140.0

# %%
mpg['horse_origin'] = np.where(mpg['horse_origin'] < 105, 'lower ' + mpg['origin'], 'upper ' + mpg['origin'])

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name horse_origin
# 0          70    usa  chevrolet chevelle malibu    upper usa
# 1          70    usa          buick skylark 320    upper usa
# 2          70    usa         plymouth satellite    upper usa
# 3          70    usa              amc rebel sst    upper usa
# 4          70    usa                ford torino    upper usa

# %%
mpg.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name  horse_origin
# 393          82     usa  ford mustang gl     lower usa
# 394          82  europe        vw pickup  lower europe
# 395          82     usa    dodge rampage     lower usa
# 396          82     usa      ford ranger     lower usa
# 397          82     usa       chevy s-10     lower usa

# %%
further_city_data = pd.DataFrame({'revenue':[7000,3400],'employee_count':[2,2]},index=['New York','Barcelona'])
city_countries = pd.DataFrame({'country':['Holland','Japan','Holland','Canada','Spain'],
                              'capital':[1,1,0,0,0]},
                             index=['Amsterdam','Tokyo','Rotterdam','Toronto','Barcelona'])
countries = pd.DataFrame({'population_mil':[17,127,37],
                         'continent':["Europe",'Asia','North America']},index=['Holland','Japan','Canada'])
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %% [markdown]
# # Series

# %%
import pandas as pd

# %%
revenues = pd.Series([555,7000,1921])
revenues
# Out:
# 0     555
# 1    7000
# 2    1921
# dtype: int64
